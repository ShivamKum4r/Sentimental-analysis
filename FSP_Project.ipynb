# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivamKum4r/Sentimental-analysis/blob/main/FSP_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression
#from sklearn.metrics import mean_squared_error, r2_score
dataset = pd.read_csv('Dataset-SA.csv')
print(dataset)
# Out:
#                                              product_name product_price Rate  \
# 0       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 1       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 2       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# 3       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    1
# 4       Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# ...                                                   ...           ...  ...
# 126020  Catvision CSR-401HP WIFI Media Streaming Devic...          1550    4
# 126021  Catvision CSR-401HP WIFI Media Streaming Devic...          1550    2
# 126022  Catvision CSR-401HP WIFI Media Streaming Devic...          1550    1
# 126023  Catvision CSR-401HP WIFI Media Streaming Devic...          1550    5
# 126024  Catvision CSR-401HP WIFI Media Streaming Devic...           155  NaN
#
#                        Review  \
# 0                      super!
# 1                     awesome
# 2                        fair
# 3             useless product
# 4                        fair
# ...                       ...
# 126020              wonderful
# 126021  slightly disappointed
# 126022              very poor
# 126023    best in the market!
# 126024                    NaN
#
#                                                   Summary Sentiment
# 0       great cooler excellent air flow and for this p...  positive
# 1                   best budget 2 fit cooler nice cooling  positive
# 2       the quality is good but the power of air is de...  positive
# 3                       very bad product its a only a fan  negative
# 4                                           ok ok product   neutral
# ...                                                   ...       ...
# 126020  good very good youtube and tv channels acchese...  positive
# 126021                          wifi not working properly  negative
# 126022                                        quality bad  negative
# 126023  awesome productworth for high price as compare...  positive
# 126024                                                NaN       NaN
#
# [126025 rows x 6 columns]

# %%
dataset.isnull().sum()
# Out:
# product_name         0
# product_price        0
# Rate                 1
# Review           24665
# Summary             11
# Sentiment            1
# dtype: int64

# %%
dataset['product_price'] = pd.to_numeric(dataset['product_price'], errors='coerce')
dataset['Rate'] = pd.to_numeric(dataset['Rate'], errors='coerce')
dataset.plot(x='Rate', y='product_price', style='o')
plt.xlabel('Rate')
plt.ylabel('Product Price')
plt.title('product_price vs Rate')
plt.show()

# %%
x=[5,4,1,3,2]
plt.bar(x,dataset['Rate'].value_counts())
# Out:
# <BarContainer object of 5 artists>
